# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\abhi\Desktop\Data Cleaning\Lending Data.xlsx')

# %%
df.shape
# Out:
# (97, 14)

# %%
df.columns
# Out:
# Index(['Name of Lending Institution', 'HQ State', 'Rank', 'TA Ratio1',
#        'TBL Ratio1', 'Amount ($1,000)', 'Number ', 'Lender Asset Size',
#        'Amount ($1,000).1', 'Number .1', 'Unnamed: 10', 'Amount ($1,000).2',
#        'Number .2', 'CC Amount/TA1'],
#       dtype='object')

# %%
df['Rank'].head()
# Out:
# 0    -1
# 1     1
# 2     2
# 3     3
# 4     4
# Name: Rank, dtype: object

# %%
pd.options.display.float_format='{:,.4f}'.format

# %%
df.tail(10)
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 87                           Goldman Sachs Group The       NY    87    0.0000
# 88                           Deutsche Bk Tc Americas       NY    88    0.0000
# 89                  USAA Svg. Bank                          NV   NR         0
# 90                                State Street Corp.       MA    NR         -
# 91                     E Trade Bk                           VA   NR         -
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
#    TBL Ratio1 Amount ($1,000) Number      Lender Asset Size  \
# 87     0.0010            4000       6  >$50B
# ...

# %%
df.dtypes
# Out:
# Name of Lending Institution     object
# HQ State                        object
# Rank                            object
# TA Ratio1                       object
# TBL Ratio1                      object
# Amount ($1,000)                 object
# Number                          object
# Lender Asset Size               object
# Amount ($1,000).1              float64
# Number .1                      float64
# Unnamed: 10                    float64
# Amount ($1,000).2              float64
# Number .2                      float64
# CC Amount/TA1                   object
# dtype: object

# %% [markdown]
# # Replacing NR values to 0 since the companies are not ranked

# %%
df['Rank'].loc[89:97:,]
# Out:
# 89     NR
# 90     NR
# 91     NR
# 92     NR
# 93     NR
# 94    NaN
# 95    NaN
# 96    NaN
# Name: Rank, dtype: object

# %%
df['Rank'].loc[89:97:,]=df['Rank'].loc[89:97:,].replace('NR',np.nan)
# Out:
# C:\Users\abhi\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df['Rank'].loc[89:97:,]
# Out:
# 89    NaN
# 90    NaN
# 91    NaN
# 92    NaN
# 93    NaN
# 94    NaN
# 95    NaN
# 96    NaN
# Name: Rank, dtype: object

# %%
df['Rank'].loc[89:97:,].replace(np.nan,'0', inplace=True)

# %%
df.tail(5)
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 92                     Charles Schwab Bk                    NV    0         -
# 93                     Third FS&LA                          OH    0         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN    0       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN    0       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN    0       NaN
#
#    TBL Ratio1 Amount ($1,000) Number      Lender Asset Size  \
# 92          -               -       -  >$10B
# 93          -               -       -  >$10B
# 94        NaN             NaN     NaN                   NaN
# 95        NaN             NaN     NaN                   NaN
# 96        NaN             NaN     NaN                   NaN
#
#     Amount ($1,000).1  Number .1  Unnamed: 10  Amount ($1,000).2  Number .2  \
# 92             0.0000     0.0000          nan             0.0000     0.0000
# ...

# %%
df['Rank'].value_counts()
# Out:
# 0     8
# 19    3
# 40    2
# 34    2
# 11    2
#      ..
# 63    1
# 64    1
# 65    1
# 66    1
# 1     1
# Name: Rank, Length: 82, dtype: int64

# %% [markdown]
# # Replacing '-' witht the column mean

# %%
df.replace('-', np.nan)
# Out:
#                           Name of Lending Institution HQ State Rank  \
# 0                                                 NaN      NaN   -1
# 1                               American Express Co.       NY     1
# 2                            First Citizens Banchares      NC     2
# 3                            Wintrust Financial Corp.      IL     3
# 4                                       Zions Bancorp      UT     4
# ..                                                ...      ...  ...
# 92                     Charles Schwab Bk                    NV    0
# 93                     Third FS&LA                          OH    0
# 94  *The bank was formerly known as GE Money Bank,...      NaN    0
# 95  1 TA = total domestic assets held by the lende...      NaN    0
# 96  Source: U.S. Small Business Administration, Of...      NaN    0
#
#     TA Ratio1  TBL Ratio1  Amount ($1,000)        Number   \
# 0     -2.0000     -3.0000          -4.0000        -5.0000
# ...

# %%
df[['TA Ratio1','TBL Ratio1','Amount ($1,000)','Number ']]= df[['TA Ratio1','TBL Ratio1','Amount ($1,000)','Number ']].replace('-', np.nan)

# %%
df['TBL Ratio1']= df['TBL Ratio1'].fillna(df['TBL Ratio1'].mean())

# %%
df['TA Ratio1']= df['TA Ratio1'].fillna(df['TA Ratio1'].mean())

# %%
df['Amount ($1,000)']= df['Amount ($1,000)'].fillna(df['Amount ($1,000)'].mean())

# %%
df['Number ']= df['Number '].fillna(df['Number '].mean())

# %%
df['CC Amount/TA1'] = df['CC Amount/TA1'].replace('.',np.nan)

# %% [markdown]
# # Removing Unnamed column

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
#   Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 0                         NaN      NaN   -1    -2.0000     -3.0000
# 1       American Express Co.       NY     1     0.2383      0.9995
# 2    First Citizens Banchares      NC     2     0.1874      0.4908
# 3    Wintrust Financial Corp.      IL     3     0.1690      0.3836
# 4               Zions Bancorp      UT     4     0.1180      0.2606
#
#    Amount ($1,000)        Number      Lender Asset Size  Amount ($1,000).1  \
# 0          -4.0000        -5.0000                    -6            -7.0000
# 1  16,350,038.0000 3,603,226.0000  >$50B                   16,318,089.0000
# 2   3,914,507.0000   117,702.0000  $10B-$50B                  378,394.0000
# 3   2,842,793.0000   136,801.0000  $10B-$50B                  800,526.0000
# 4   6,231,770.0000    52,612.0000  >$50B                      526,206.0000
#
#        Number .1  Amount ($1,000).2   Number .2 CC Amount/TA1
# ...

# %% [markdown]
# # Replacing '-' witht the column mean

# %%
df[['Amount ($1,000).1','Number .1','Amount ($1,000).2','Number .2']]= df[['Amount ($1,000).1','Number .1','Amount ($1,000).2','Number .2']].replace('-', np.nan)

# %%
df['Amount ($1,000).1']= df['Amount ($1,000).1'].fillna(df['Amount ($1,000).1'].mean())

# %%
df['Number .1']= df['Number .1'].fillna(df['Number .1'].mean())

# %%
df['Amount ($1,000).2']= df['Amount ($1,000).2'].fillna(df['Amount ($1,000).2'].mean())

# %%
df['Number .2']= df['Number .2'].fillna(df['Number .2'].mean())

# %%
df.tail(5)
# Out:
#                           Name of Lending Institution HQ State Rank  \
# 92                     Charles Schwab Bk                    NV    0
# 93                     Third FS&LA                          OH    0
# 94  *The bank was formerly known as GE Money Bank,...      NaN    0
# 95  1 TA = total domestic assets held by the lende...      NaN    0
# 96  Source: U.S. Small Business Administration, Of...      NaN    0
#
#     TA Ratio1  TBL Ratio1  Amount ($1,000)      Number      Lender Asset Size  \
# 92     0.0259      0.2147   3,149,404.4778 214,014.2444  >$10B
# 93     0.0259      0.2147   3,149,404.4778 214,014.2444  >$10B
# 94     0.0259      0.2147   3,149,404.4778 214,014.2444                   NaN
# 95     0.0259      0.2147   3,149,404.4778 214,014.2444                   NaN
# 96     0.0259      0.2147   3,149,404.4778 214,014.2444                   NaN
#
#     Amount ($1,000).1    Number .1  Amount ($1,000).2  Number .2 CC Amount/TA1
# ...

# %% [markdown]
# # Dropping last 3 rows

# %%
df.drop(index=[94,95,96], inplace=True)

# %%
df.head()
# Out:
#   Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 0                         NaN      NaN   -1    -2.0000     -3.0000
# 1       American Express Co.       NY     1     0.2383      0.9995
# 2    First Citizens Banchares      NC     2     0.1874      0.4908
# 3    Wintrust Financial Corp.      IL     3     0.1690      0.3836
# 4               Zions Bancorp      UT     4     0.1180      0.2606
#
#    Amount ($1,000)        Number      Lender Asset Size  Amount ($1,000).1  \
# 0          -4.0000        -5.0000                    -6            -7.0000
# 1  16,350,038.0000 3,603,226.0000  >$50B                   16,318,089.0000
# 2   3,914,507.0000   117,702.0000  $10B-$50B                  378,394.0000
# 3   2,842,793.0000   136,801.0000  $10B-$50B                  800,526.0000
# 4   6,231,770.0000    52,612.0000  >$50B                      526,206.0000
#
#        Number .1  Amount ($1,000).2   Number .2 CC Amount/TA1
# ...

# %%
df.drop(index=0, inplace=True)

# %%
df
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY     1     0.2383      0.9995
# 2            First Citizens Banchares      NC     2     0.1874      0.4908
# 3            Wintrust Financial Corp.      IL     3     0.1690      0.3836
# 4                       Zions Bancorp      UT     4     0.1180      0.2606
# 5             Synovus Financial Corp.      GA     5     0.1623      0.3814
# ..                                ...      ...  ...        ...         ...
# 89  USAA Svg. Bank                          NV    0     0.0000      0.2147
# 90                State Street Corp.       MA     0     0.0259      0.2147
# 91     E Trade Bk                           VA    0     0.0259      0.2147
# 92     Charles Schwab Bk                    NV    0     0.0259      0.2147
# 93     Third FS&LA                          OH    0     0.0259      0.2147
#
# ...

# %%
df.dtypes
# Out:
# Name of Lending Institution     object
# HQ State                        object
# Rank                           float64
# TA Ratio1                      float64
# TBL Ratio1                     float64
# Amount ($1,000)                float64
# Number                         float64
# Lender Asset Size                int32
# Amount ($1,000).1              float64
# Number .1                      float64
# Amount ($1,000).2              float64
# Number .2                      float64
# CC Amount/TA1                  float64
# dtype: object

# %% [markdown]
# # Updating the data type and replace '.' with the column mean

# %%
df['Rank']=df['Rank'].astype(float)

# %%
df['CC Amount/TA1']= df['CC Amount/TA1'].replace('    .  ',np.nan)

# %%
df['CC Amount/TA1']=df['CC Amount/TA1'].astype(float)

# %%
df['CC Amount/TA1']= df['CC Amount/TA1'].replace(np.nan,df['CC Amount/TA1'].mean())

# %% [markdown]
# # Encoding Lender Asset Size to based on levels

# %%
df['Lender Asset Size'].value_counts()
# Out:
# 1    43
# 2    32
# 0    18
# Name: Lender Asset Size, dtype: int64

# %%
df['Lender Asset Size'] = df['Lender Asset Size'].replace(regex=True, to_replace='[^0-9]', value='')

# %%
from sklearn.preprocessing import LabelEncoder
df['Lender Asset Size'] = LabelEncoder().fit_transform(df['Lender Asset Size'])

# %%
df
# Out:
#           Name of Lending Institution HQ State   Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY  1.0000     0.2383      0.9995
# 2            First Citizens Banchares      NC  2.0000     0.1874      0.4908
# 3            Wintrust Financial Corp.      IL  3.0000     0.1690      0.3836
# 4                       Zions Bancorp      UT  4.0000     0.1180      0.2606
# 5             Synovus Financial Corp.      GA  5.0000     0.1623      0.3814
# ..                                ...      ...    ...        ...         ...
# 89  USAA Svg. Bank                          NV 0.0000     0.0000      0.2147
# 90                State Street Corp.       MA  0.0000     0.0259      0.2147
# 91     E Trade Bk                           VA 0.0000     0.0259      0.2147
# 92     Charles Schwab Bk                    NV 0.0000     0.0259      0.2147
# 93     Third FS&LA                          OH 0.0000     0.0259      0.2147
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         93 non-null     float64
#  3   TA Ratio1                    93 non-null     float64
#  4   TBL Ratio1                   93 non-null     float64
#  5   Amount ($1,000)              93 non-null     float64
#  6   Number                       93 non-null     float64
#  7   Lender Asset Size            93 non-null     int32
#  8   Amount ($1,000).1            93 non-null     float64
#  9   Number .1                    93 non-null     float64
#  10  Amount ($1,000).2            93 non-null     float64
#  11  Number .2                    93 non-null     float64
# ...

# %% [markdown]
# # After data cleaning

# %%
df
# Out:
#           Name of Lending Institution HQ State   Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY  1.0000     0.2383      0.9995
# 2            First Citizens Banchares      NC  2.0000     0.1874      0.4908
# 3            Wintrust Financial Corp.      IL  3.0000     0.1690      0.3836
# 4                       Zions Bancorp      UT  4.0000     0.1180      0.2606
# 5             Synovus Financial Corp.      GA  5.0000     0.1623      0.3814
# ..                                ...      ...    ...        ...         ...
# 89  USAA Svg. Bank                          NV 0.0000     0.0000      0.2147
# 90                State Street Corp.       MA  0.0000     0.0259      0.2147
# 91     E Trade Bk                           VA 0.0000     0.0259      0.2147
# 92     Charles Schwab Bk                    NV 0.0000     0.0259      0.2147
# 93     Third FS&LA                          OH 0.0000     0.0259      0.2147
#
# ...
